# %%
print("promit")
# Out:
# promit

# %%
name = "promit"
print(name)
# Out:
# promit

# %%
name = "promit,minu,probir"
print(name)
# Out:
# promit,minu,probir

# %%
name = "promit","minu","probir"
print(name)
# Out:
# ('promit', 'minu', 'probir')

# %%
a = 10 
b = 30
print(a+b)
# Out:
# 40

# %%
e = input("please enter a  number ")
print(e)
