# %%
import requests
import pandas as pd
import json

# %%
#  api connect 
postal = requests.get("https://api.postalpincode.in/pincode/732101")
print(postal.json())

postal_1 = postal.json()
postal_2 = postal_1[0]
postal_3 = postal_2["PostOffice"]

print()
print()
for i in postal_3:
    x = i.get("Name")
    y = i.get("Description")
    z = i.get("BtanchType")
    a = i.get("DeliveryStatus")
    b = i.get("Circle")
    c = i.get("BtanchType")
    print(x)
# Out:
# [{'Message': 'Number of pincode(s) found:11', 'Status': 'Success', 'PostOffice': [{'Name': 'Baluchar', 'Description': None, 'BranchType': 'Sub Post Office', 'DeliveryStatus': 'Non-Delivery', 'Circle': 'West Bengal', 'District': 'Malda', 'Division': 'Malda', 'Region': 'North Bengal And Sikkim', 'Block': 'Englishbazar', 'State': 'West Bengal', 'Country': 'India', 'Pincode': '732101'}, {'Name': 'Bansbari', 'Description': None, 'BranchType': 'Sub Post Office', 'DeliveryStatus': 'Non-Delivery', 'Circle': 'West Bengal', 'District': 'Malda', 'Division': 'Malda', 'Region': 'North Bengal And Sikkim', 'Block': 'Englishbazar', 'State': 'West Bengal', 'Country': 'India', 'Pincode': '732101'}, {'Name': 'District School Board (Malda)', 'Description': None, 'BranchType': 'Sub Post Office', 'DeliveryStatus': 'Non-Delivery', 'Circle': 'West Bengal', 'District': 'Malda', 'Division': 'Malda', 'Region': 'North Bengal And Sikkim', 'Block': 'Englishbazar', 'State': 'West Bengal', 'Country': 'India', 'Pinc
# ...

# %%
stocks = {
        'AAPL': 187.31,
        'MSFT': 124.06,
        'FB': 183.50
    }

for key, value in stocks.items() :
    print(key + " : " + str(value))
# Out:
# AAPL : 187.31
# MSFT : 124.06
# FB : 183.5
