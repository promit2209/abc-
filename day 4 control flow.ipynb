# %% [markdown]
# # if statement

# %% [markdown]
# write a program to calculate the percentage of a student in the subjects maths science social english and hindi

# %%
x = input("enter the student name:")
a = int(input("enter the marks in maths:"))
b = int(input("enter the marks in science:"))
c = int(input("enter the marks in social:"))
d = int(input("enter the marks in eng:"))
e = int(input("enter the marks in hindi:"))
n =  (((a+b+c+d+e)/500)*100)

print("percentage of the stident:",n)
# Out:
# enter the student name:promit
# enter the marks in maths:85
# enter the marks in science:99
# enter the marks in social:70
# enter the marks in eng:89
# enter the marks in hindi:99
# percentage of the stident: 88.4

# %% [markdown]
# if percentage is above 90 aasined a grade
# if percentage is above 90 aasined a grade
# if percentage is above 90 aasined a grade

# %%
q = int(input("enter the the percentage"))
if q>= 90:
    print("A grade")
if q< 90 and q>=75:
    print ("b grade")
if q<75 and q>=60:
    print("c grade")
# Out:
# enter the the percentage95
# A grade

# %% [markdown]
# # if else state ment

# %% [markdown]
# write a program to display hello if the no is multiple of 5

# %%
q = int(input("enter the no"))
if q%5==0:
    print("hello")
else:
    print("bye")
# Out:
# enter the no65
# hello

# %%
a = int(input("enter the no :"))
if a>0:
    print("positive no")
else:
    print("negative no")
# Out:
# enter the no :55
# positive no

# %% [markdown]
# # if elif else

# %% [markdown]
# write a program accept the city and print its monument
#
# delhi=redfort
# Agra= tajMahal
# Jaipur=Jai mahal
# orissa=konak temple
# hydrabad=charminar
# others=records are not found

# %%
city = str(input("enter the city"))
if city=="delhi":
    print("Redfort")
elif city=="agra":
    print("Tajmahal")
elif city=="jaipur":
    print("Jalmahal")
    
elif city=="orissa":
    print("konak temple")
    
elif city=="hydrabad":
    print("charminar")
else:
    print("no record found")
# Out:
# enter the citykolkata
# no record found

# %% [markdown]
# # nested if

# %% [raw]
# if condition:
#     If condition:
#           If condition:
#                   If condition:
#                           If condition:
#                                   If condition:
