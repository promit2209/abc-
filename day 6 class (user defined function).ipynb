# %% [markdown]
# # USER DEFINED FUNCTION:

# %%
def student():
    print("hello class")
    print("we are learning function")

# %% [markdown]
# calling the function

# %%
student()
# Out:
# hello class
# we are learning function

# %%
def school():
    print ("school-rkmvvm")
    print( "861739972")
    print("rkmvvm@gmail.com")

# %%
school()
# Out:
# school-rkmvvm
# 861739972
# rkmvvm@gmail.com

# %%
def school():
    print ("school-rkmvvm")
    print( "861739972")
    print("rkmvvm@gmail.com")

# %%
for i in range (1):
        x = input("enter the student name:")
        a = int(input("enter the marks in maths:"))
        b = int(input("enter the marks in science:"))
        c = int(input("enter the marks in social:"))
        d = int(input("enter the marks in eng:"))
        e = int(input("enter the marks in hindi:"))
        n =  (((a+b+c+d+e)/500)*100)
        print("percentage of the stident:",n)
        school()
# Out:
# enter the student name:p[romit
# enter the marks in maths:89
# enter the marks in science:65
# enter the marks in social:98
# enter the marks in eng:94
# enter the marks in hindi:9
# percentage of the stident: 71.0
# school-rkmvvm
# 861739972
# rkmvvm@gmail.com

# %% [markdown]
# # Arguments

# %%
def my_function(student_name):
    print(student_name+" "+"sharma")

# %%
my_function("puja")
# Out:
# puja sharma

# %% [markdown]
# #2 arguments passing

# %%
def my_function2(f_name,l_name):
    print(f_name+" "+l_name)

# %%
  my_function2("promit","mohanta")
# Out:
# promit mohanta

# %% [markdown]
# #write a program, to calculate the elctricity bill
#
# if  500 unit used pay rs 5 for each unit
# if  700 unit used pay rs 10 for each unit
# if  1000 unit used pay rs 15 for each unit
# if more than 1000 unit used pay rs 20 for each unit

# %%
def electricity_bill(n):
    if n<=500:
        print("total bil:",n*5)
    elif n>500 and n<=700:
        print("total bill",n*10)
        
    elif n>700 and n<=1000:
        print("total bill",n*15)
        
    elif n>1000:
        print("total bill",n*20)

# %%
def instructin(): 
    print("last date of bill mayjment is 20 april")
    print("after 20 april you need to pay 1000  as a fine")
    print("address malda")

# %%
for i in range(2):
    q= input("customer name:")
    n= int(input(" total unit:"))
    print()
    electricity_bill(n)
    instruction()
