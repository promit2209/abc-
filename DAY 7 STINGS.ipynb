# %% [markdown]
# CREATE STRING

# %%
A="HELLO WORLD"
print(A)
# Out:
# HELLO WORLD

# %%
d="today is our 1st class"
print(d)
print(type(d))
# Out:
# today is our 1st class
# <class 'str'>

# %%
c="""Anatomically modern humans first arrived on the Indian subcontinent between 73,000 and 55,000 years ago.[1] The earliest known human remains in South Asia date to 30,000 years ago. Sedentariness began in South Asia around 7000 BCE;[2] by 4500 BCE, settled life had spread,[2] and gradually evolved into the Indus Valley Civilisation, which flourished between 2500 BCE and 1900 BCE in present-day Pakistan and north-western India. Early in the second millennium BCE, persistent drought caused the population of the Indus Valley to scatter from large urban centres to villages. Indo-Aryan tribes moved into the Punjab from Central Asia in several waves of migration. The Vedic Period of the Vedic people in northern India (1500–500 BCE) was marked by the composition of their extensive collections of hymns (Vedas). The social structure was loosely stratified via the varna system, incorporated into the highly evolved present-day Jāti system. The pastoral and nomadic Indo-Aryans spread from the Punjab into the Gangetic plain. Around 600 BCE, a new, interregional culture arose; then, small chieftaincies (janapadas) were consolidated into larger states (mahajanapadas). Second urbanization took place, which came with the rise of new ascetic movements and religious concepts,[3] including the rise of Jainism and Buddhism. The latter was synthesized with the preexisting religious cultures of the subcontinent, giving rise to Hinduism."""
print(c)
# Out:
# Anatomically modern humans first arrived on the Indian subcontinent between 73,000 and 55,000 years ago.[1] The earliest known human remains in South Asia date to 30,000 years ago. Sedentariness began in South Asia around 7000 BCE;[2] by 4500 BCE, settled life had spread,[2] and gradually evolved into the Indus Valley Civilisation, which flourished between 2500 BCE and 1900 BCE in present-day Pakistan and north-western India. Early in the second millennium BCE, persistent drought caused the population of the Indus Valley to scatter from large urban centres to villages. Indo-Aryan tribes moved into the Punjab from Central Asia in several waves of migration. The Vedic Period of the Vedic people in northern India (1500–500 BCE) was marked by the composition of their extensive collections of hymns (Vedas). The social structure was loosely stratified via the varna system, incorporated into the highly evolved present-day Jāti system. The pastoral and nomadic Indo-Aryans spread from the Punjab into the Gangetic plain. Around 600 BCE, a new, interregional culture arose; then, small chieftaincies (janapadas) were consolidated into larger states (mahajanapadas). Second urbanization took place, which came with the rise of new ascetic movements and religious concepts,[3] including the rise of Jainism and Buddhism. The latter was synthesized with the preexisting religious cultures of the subcontinent, giving rise to Hinduism.

# %% [markdown]
# INDEXING IN STRING

# %%
a = "hello students"
print(a[11])
print(a[-2])
# Out:
# n
# t

# %%
a = "how's ypur studies going on?"
print(a[-1])
# Out:
# ?

# %% [markdown]
# SLICING IN THE STRING

# %%
a = "hellostudents how are you ?"
print(a[0:5])
# Out:
# hello

# %%
a = "hello students how are you ?"
print(a[6:18])
# Out:
# students how

# %%
a = "hello students how are you ?"
print(a[0:20:2])
# Out:
# hlosuet o

# %% [markdown]
# # reversing in the string

# %%
a = "hello students how are you ?"
print(a[0:0:-1])

# %%
a = "hello students how are you ?"
print(a[::-1])
# Out:
# ? uoy era woh stneduts olleh

# %% [markdown]
# # finding a lengthof a string

# %%
a = "hello students how are you ?"
print(len(a))
# Out:
# 28

# %%
b="hello world"
print(b)
print(len(b))
# Out:
# hello world
# 11

# %% [markdown]
# # upper method

# %%
a = "hello how are you"
print(a.upper())
# Out:
# HELLO HOW ARE YOU

# %% [markdown]
# # lower method

# %%
a = "HELLO HOW ARE YOU"
print(a.lower())
# Out:
# hello how are you

# %% [markdown]
# # replace function

# %%
a = "HELLO HOW ARE YOU"
print(a.replace("HELLO","BYE"))
# Out:
# BYE HOW ARE YOU

# %%
b="hello world"
print(b.replace("hello","student"))
# Out:
# student world

# %% [markdown]
# # find method

# %%
a ="pyton is great"
b= a.find("p")
print(b)
# Out:
# 0

# %%
a ="pyton is great"
b= a.find("g")
print(b)
# Out:
# 9

# %% [markdown]
# # string reverse

# %%
a= " my name is promit"
b= a.split()
c= b[-1::-1]
d= ''.join(c)
print(b)
print(c)
print(d)
# Out:
# ['my', 'name', 'is', 'promit']
# ['promit', 'is', 'name', 'my']
# promitisnamemy

# %%
print(b[-1::-1])
# Out:
# ['promit', 'is', 'name', 'my']
