# %% [markdown]
# # variables

# %%
x=y=z="orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
a=1
print(a)
# Out:
# 1

# %%
b=1
c=2,3
print(b,c)
# Out:
# 1 (2, 3)

# %% [markdown]
# many values to multiple variables

# %%
x,y,z= "orange","babanana","cherry"
print(x,y,z)
# Out:
# orange babanana cherry

# %% [markdown]
# #   python out put variables

# %%
x = "python" 
y= "is "
z = "amazing"

print(x,y,z)

print()

print(x)
print(y)
print(z)
# Out:
# python is  amazing
#
# python
# is
# amazing

# %% [markdown]
# # operators

# %% [markdown]
# data types

# %%
x= 2
print(x)
print(type(x))
# Out:
# 2
# <class 'int'>

# %%
x= 2.5
print(x)
print(type(x))
# Out:
# 2.5
# <class 'float'>

# %%
x= 2+5j
print(x)
print(type(x))
# Out:
# (2+5j)
# <class 'complex'>

# %%
z= "this is the day two of python class"
print(z)
print(type(z))
# Out:
# this is the day two of python class
# <class 'str'>

# %%
y=[1,12,3,4,5,6,7,8]
print(y)
print(type(y))
# Out:
# [1, 12, 3, 4, 5, 6, 7, 8]
# <class 'list'>

# %%
b=(1,12,3,4,5,6,7,8)
print(b)
print(type(b))
# Out:
# (1, 12, 3, 4, 5, 6, 7, 8)
# <class 'tuple'>

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        1
# b          tuple      n=8
# c          tuple      n=2
# x          complex    (2+5j)
# y          list       n=8
# z          str        this is the day two of python class

# %% [markdown]
# # OPERATORS IN PYTHON

# %% [markdown]
# # (+)  OPERATOR

# %%
A=5
B=6
print(A+B)
# Out:
# 11

# %%
A=5
B=6+6j
print(A+B)
# Out:
# (11+6j)

# %%
a = "promit "
b =  "hello"
print(a+""+b)
# Out:
# promit hello

# %% [markdown]
# # substrsction

# %%
A=455
B=6
print(A-B)
# Out:
# 449

# %% [markdown]
# ****in string we use only plus opeartor

# %% [markdown]
# # multiplication

# %%
A=5
B=6
print(A*B)
# Out:
# 30

# %% [markdown]
# # division

# %%
A=30
B=6
print(A/B)
# Out:
# 5.0

# %% [markdown]
# # modulus

# %%
A=5
B=6
print(A%B)
# Out:
# 5

# %% [markdown]
# # exponenet operator

# %%
a = 2554566
print(a**5)
# Out:
# 108789163694784434543086007892576

# %% [markdown]
# # equqtion

# %%
a = (25/50)+(98/4)*5
print(a)
# Out:
# 123.0

# %% [markdown]
# # or operator

# %%
A = False
B = False
print(A or B)
# Out:
# False
