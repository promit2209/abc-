# %% [markdown]
# # create dictionary

# %%
a = { "id" : "12345as",
     "colour" : "black",
     "year": 1960}
print(a)
print(type(a))
# Out:
# {'id': '12345as', 'colour': 'black', 'year': 1960}
# <class 'dict'>

# %%
a = { "id" : "12345as",
     "colour" : "black",
     "year": 1960}
print(a)
print(type(a))
print(a["colour"])
# Out:
# {'id': '12345as', 'colour': 'black', 'year': 1960}
# <class 'dict'>
# black

# %%
a = { "id" : "12345as",
     "colour" : "black",
     "year": 1960,
    "year":2000}
print(a)
# Out:
# {'id': '12345as', 'colour': 'black', 'year': 2000}

# %% [markdown]
# # dictionary length

# %%
a = { "id" : "12345as",
     "colour" : "black",
     "year": 1960,
    "year":2000}
print(a)
print(len(a))
# Out:
# 3

# %%
dict = { "id" : "12345as",
     "colour" : "black",
     "year": 1960,
    "year":2000,
    "a":[1,2,3,4,5,6],
    "b":(2.2,3.3,4.4,5.5),
       "c":False}
print(dict)
# Out:
# {'id': '12345as', 'colour': 'black', 'year': 2000, 'a': [1, 2, 3, 4, 5, 6], 'b': (2.2, 3.3, 4.4, 5.5), 'c': False}

# %% [markdown]
# # dictionar costructor

# %%
a = {"name" : "swati","age":27,"country":"india"}
print(a["name"])
# Out:
# swati

# %% [markdown]
# # get method

# %%
a = {"name" : "swati","age":27,"country":"india"}
print(a.get("name"))
# Out:
# swati

# %%
a = {"name" : "swati","age":27,"country":"india"}
x =a.keys()
print(x)
# Out:
# dict_keys(['name', 'age', 'country'])

# %%
a = {"name" : "swati","age":27,"country":"india"}
y = a.values()
print(y)
# Out:
# dict_values(['swati', 27, 'india'])

# %%
a = {"name" : "swati","age":27,"country":"india"}
a["age"]= 28
print(a)
# Out:
# {'name': 'swati', 'age': 28, 'country': 'india'}

# %% [markdown]
# # adding in dictionary

# %%
a = {"name" : "swati","age":27,"country":"india"}
a.update({"mail id":"456@gmail.com"})
print(a)
# Out:
# {'name': 'swati', 'age': 27, 'country': 'india', 'mail id': '456@gmail.com'}

# %% [markdown]
# # delete something in dictionary

# %%
a = {"name" : "swati","age":27,"country":"india"}
a.pop("age")
print(a)
# Out:
# {'name': 'swati', 'country': 'india'}

# %%
a = {"name" : "swati","age":27,"country":"india"}
print(a)
del a ["name"]
# Out:
# {'age': 27, 'country': 'india'}

# %%
a = {"name" : "swati","age":27,"country":"india"}
a.clear()
print(a)
print(type(a))
# Out:
# {}
# <class 'dict'>

# %% [markdown]
# # concatination in dictionary

# %%
dict1 ={1:10,2:20}
dict2 ={3:30,4:40}
dict3 ={5:50,6:60}
dict4 ={3:30,4:40}
for d in (dict1,dict2,dict3):
    dict4.update(d)
    print(dict4)
# Out:
# {3: 30, 4: 40, 1: 10, 2: 20}
# {3: 30, 4: 40, 1: 10, 2: 20}
# {3: 30, 4: 40, 1: 10, 2: 20, 5: 50, 6: 60}

# %%
d = {}
for x in range(1,16):
    d[x]= x**2
    print(d)
# Out:
# {1: 1}
# {1: 1, 2: 4}
# {1: 1, 2: 4, 3: 9}
# {1: 1, 2: 4, 3: 9, 4: 16}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %% [markdown]
# # check whether a given key already exixts in a dictionary

# %%
d = {1:10,2:20,3:30,4:40,5:50,6:60}
def key_present(x):
    if x in d :
        print("key is present in the dictionary")
    else:
        print("key is not psesent in the dictionary")

# %%
key_present(5)
# Out:
# key is present in the dictionary

# %%
key_present(8)
# Out:
# key is not psesent in the dictionary
